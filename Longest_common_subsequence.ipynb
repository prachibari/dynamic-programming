# %% [markdown]
# # Longest Common Sub sequence
# Given two sequences, find the length of longest subsequence present in both of them. A subsequence is a sequence that appears in the same relative order, but not necessarily contiguous. For example, “abc”, “abg”, “bdf”, “aeg”, ‘”acefg”, .. etc are subsequences of “abcdefg”. So a string of length n has 2^n different possible subsequences.

# %% [markdown]
# 1. Recursion - Top down approach
# 2. Dynamic Programming - Bottom down approach
#
# ### memoization
# storing results of recursion. Since in recursion branches overlap. Using this the complexity is decreased from O(2^n) to O(m*n)
#
#
# #### Complexity
# ----------
# * Recursive Solution: O(2^n) (or O(2^m) whichever of n and m is larger).
# * Dynamic Programming Solution: O(n * m)

# %%
from IPython.display import Image
Image(filename="lcs1.png",width=400,height=200)

# %%
Image(filename="lcs2.png",width=400,height=200)

# %%
#using Dynamic Programming

def lcs(X,Y):
    m = len(string1)
    n = len(string2)
   
    # declaring the array for storing the dp values 
    L = [[None]*(n + 1) for i in range(m + 1)]   
    
    #you're filling the table top to bottom and using it bottom up
    for i in range(m + 1): 
        for j in range(n + 1): 
            if i == 0 or j == 0 : 
                L[i][j] = 0
            elif X[i-1] == Y[j-1]: 
                L[i][j] = L[i-1][j-1]+1  #take diagonal element +1
            else: 
                L[i][j] = max(L[i-1][j], L[i][j-1]) #take max of either diagonal element
    return L[m][n]

# %%
string1 = "AGGTAB"
string2 = "GXTXAYB"
print("Length of LCS {0} ".format(lcs(string1,string2)))
# Out:
# Length of LCS 4
